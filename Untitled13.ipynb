# %% [markdown]
# <a href="https://colab.research.google.com/github/dharshkutty29-cmd/Data-analysis-using-python-/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample Dataset
data = {
    "Product": ["Laptop", "Phone", "Headphones", "Laptop", "Phone", None, "Tablet", "Laptop"],
    "Month": ["Jan", "Jan", "Feb", "Feb", "Mar", "Mar", "Apr", "Apr"],
    "Sales": [50000, 30000, 10000, 55000, np.nan, 25000, 20000, 50000]
}

df = pd.DataFrame(data)

# Add Duplicate Row
df = pd.concat([df, df.iloc[[0]]], ignore_index=True)

print("Original Dataset")
print(df)

# Data Cleaning
df["Product"] = df["Product"].fillna("Unknown")
df["Sales"] = df["Sales"].fillna(df["Sales"].mean())
df = df.drop_duplicates()

print("\nCleaned Dataset")
print(df)

# Top Selling Products
product_sales = df.groupby("Product")["Sales"].sum()

print("\nTop Selling Products")
print(product_sales.sort_values(ascending=False))

# Monthly Sales Trend
monthly_sales = df.groupby("Month")["Sales"].sum()

print("\nMonthly Sales Trend")
print(monthly_sales)

plt.figure(figsize=(8,5))
product_sales.plot(kind="bar")
plt.title("Top Selling Products")
plt.xlabel("Products")
plt.ylabel("Revenue")
plt.show()

plt.figure(figsize=(8,5))
monthly_sales.plot(kind="line", marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()
# Out:
# Original Dataset
#       Product Month    Sales
# 0      Laptop   Jan  50000.0
# 1       Phone   Jan  30000.0
# 2  Headphones   Feb  10000.0
# 3      Laptop   Feb  55000.0
# 4       Phone   Mar      NaN
# 5        None   Mar  25000.0
# 6      Tablet   Apr  20000.0
# 7      Laptop   Apr  50000.0
# 8      Laptop   Jan  50000.0
#
# Cleaned Dataset
#       Product Month    Sales
# 0      Laptop   Jan  50000.0
# 1       Phone   Jan  30000.0
# 2  Headphones   Feb  10000.0
# 3      Laptop   Feb  55000.0
# 4       Phone   Mar  36250.0
# 5     Unknown   Mar  25000.0
# 6      Tablet   Apr  20000.0
# 7      Laptop   Apr  50000.0
#
# Top Selling Products
# Product
# Laptop        155000.0
# Phone          66250.0
# Unknown        25000.0
# Tablet         20000.0
# Headphones     10000.0
# Name: Sales, dtype: float64
#
# Monthly Sales Trend
# Month
# Apr    70000.0
# Feb    65000.0
# Jan    80000.0
# Mar    61250.0
# Name: Sales, dtype: float64
